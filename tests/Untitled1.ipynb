# %%
import json  
import numpy
import pandas as pd  
from pandas.io.json import json_normalize  
import requests
import io
import os

# %%
PATH=''
ENRICHMENT_TABLE_ID = '5d28fdeb7f099927ae2c2cd4'
BIG_PANDA_BEARER='4f1fb77d27cad48d23b189c4014414b3'


def import_json( j_file ):
    print ("importing data from {} ...".format(j_file))
    with open(os.path.join(PATH, j_file), encoding='utf-8') as f: 
        d = json.load(f) 
    
    df = json_normalize(d['records']) 
    print ('done. {}'.format(df.shape))
    return df


def generate_csv ( path, df, rows=0 ):   
    print('exporting csv...')
    if(rows<=0):
        df.to_csv(path,index=False)
    else:
        df.head(rows).to_csv(path,index=False)

    return

def send_data_bigpanda ( df, rows =0 ):
    
    print('exporting data to bigpanda...')

    s_buf = io.StringIO()
    generate_csv(s_buf, df)
    
    url = "https://api.bigpanda.io/resources/v1.0/enrichments/{}/map".format(ENRICHMENT_TABLE_ID)

    #print(url);

    headers = {
        'Authorization': "Bearer {}".format(BIG_PANDA_BEARER),
        'Content-Type': "text/csv;charset=utf8"
        }

    #print (headers)

    response = requests.request("POST", url, headers=headers, data=s_buf.getvalue().encode('utf-8'), stream=True)
    print('Result from bigpanda: {} \r\n{}'.format(response, response.text))

# %%
print('\r\n **** TIVIT AIOPS **** - Import CMDB to BIGPANDA\r\n\r\n')

print('starting importing jsons...')
#load jsons to pandas dataframe  
df_so = import_json('cmdb_server_bigpanda.json')
df_rel = import_json('cmdb_relacionamento_bigpanda.json')
df_cmdb = import_json('cmdb_bigpanda.json')


print('\r\nsanitizing cmdb fields...')
#remover | dos names pois são usados como array no bigpanda.
df_cmdb['name'] = df_cmdb['name'].str.replace('|','-').str.replace('\n',' ')
df_cmdb['fqdn'] = df_cmdb['fqdn'].str.replace('|','-').str.replace('\n',' ')
df_cmdb['ip_address'] = df_cmdb['ip_address'].str.replace('\n',' ')


print('extracting dataframes relationships...')

print('extracting cluster information from cmdb...')
df_clusters= df_rel.merge(df_cmdb[(df_cmdb.sys_class_name=='cmdb_ci_cluster')], left_on='parent', right_on='sys_id', how='inner')[['parent', 'sys_id','child', 'name', 'company.name']]

print('extracting businessapp from cmdb...')
df_business_app= df_rel.merge(df_cmdb[(df_cmdb.sys_class_name=='cmdb_ci_business_app')], left_on='parent', right_on='sys_id', how='inner')[['parent', 'sys_id','child', 'name', 'company.name']]

print('extractig services from cmdb...')
df_service= df_rel.merge(df_cmdb[(df_cmdb.sys_class_name=='cmdb_ci_service')], left_on='parent', right_on='sys_id', how='inner')[['parent', 'sys_id','child', 'name', 'company.name']]

print('extracting aplication from cmdb...')
df_application= df_rel.merge(df_cmdb[df_cmdb.sys_class_name.isin(['cmdb_ci_application_software','cmdb_ci_appl'])], left_on='parent', right_on='sys_id', how='inner')[['parent', 'sys_id','child', 'name', 'company.name']]

print('extracting operating systems from cmdb...')
df_os= df_so[['name', 'fqdn', 'os', 'os_version']].drop_duplicates()    

print('create relationships with cmdb values(fqdn, sys_id)')
df_rel2=df_rel.merge(df_cmdb, left_on='parent', right_on='sys_id').merge(df_cmdb, left_on='child', right_on='sys_id')[['child', 'parent', 'name_x', 'sys_class_name_x', 'name_y','sys_class_name_y']].rename(columns={
'child':'child',
'parent':'parent',
'name_x':'parent_name',
'sys_class_name_x':'parent_sys_class_name',
'name_y':'child_name',
'sys_class_name_y':'child_sys_class_name'})



print('creating grouping and merging dataframes...')
#dados cluster
df1= df_cmdb.merge(df_clusters, left_on='sys_id',right_on='child', how='inner')[['sys_id_x','name_x', 'name_y']].groupby(['sys_id_x','name_x'])['name_y'].apply(list).to_frame().reset_index().rename(columns={'sys_id_x':'sys_id','name_x':'name_x','name_y':'parents'})  
#dados childs
df2= df_cmdb.merge(df_rel2, left_on='sys_id',right_on='parent', how='inner')[['sys_id','name', 'child_name']].groupby(['sys_id','name'])['child_name'].apply(list).to_frame().reset_index().rename(columns={'sys_id':'sys_id','name':'name_x','child_name':'childs'})  
#dados parents
df3= df_cmdb.merge(df_rel2, left_on='sys_id',right_on='child', how='inner')[['sys_id','name', 'parent_name']].groupby(['sys_id','name'])['parent_name'].apply(list).to_frame().reset_index().rename(columns={'sys_id':'sys_id','name':'name_x','parent_name':'clusters'}) 
#dados os
df4= df_cmdb.merge(df_os, left_on=['name','fqdn'],right_on=['name','fqdn'], how='inner')[['sys_id','name', 'os']].groupby(['sys_id','name'])['os'].apply(list).to_frame().reset_index().rename(columns={'sys_id':'sys_id','name':'name_x','os':'so'}) 
#dados application
df5= df_cmdb.merge(df_application, left_on='sys_id',right_on='child', how='inner')[['sys_id_x','name_x', 'name_y']].groupby(['sys_id_x','name_x'])['name_y'].apply(list).to_frame().reset_index().rename(columns={'sys_id_x':'sys_id','name_x':'name_x','name_y':'apps'})
#dados services
df6= df_cmdb.merge(df_service, left_on='sys_id',right_on='child', how='inner')[['sys_id_x','name_x', 'name_y']].groupby(['sys_id_x','name_x'])['name_y'].apply(list).to_frame().reset_index().rename(columns={'sys_id_x':'sys_id','name_x':'name_x','name_y':'services'})
#dados business application
df7= df_cmdb.merge(df_business_app, left_on='sys_id',right_on='child', how='inner')[['sys_id_x','name_x', 'name_y']].groupby(['sys_id_x','name_x'])['name_y'].apply(list).to_frame().reset_index().rename(columns={'sys_id_x':'sys_id','name_x':'name_x','name_y':'business_app'})
print('done')

# print ('clusters',df_clusters.shape)
# print ('df_cmdb',df_cmdb.shape)
# print ('df_application',df_application.shape)
# print ('df_business_app',df_business_app.shape)
# print ('df_service',df_service.shape)
# print ('df_os',df_os.shape)
# print ('df_rel2',df_rel2.shape)  


print('\r\ngenerating final dataframe ...')
#generating final dataframe
df_final=df_cmdb.merge(df1, left_on='sys_id',right_on='sys_id', how='left').merge(df2, left_on='sys_id',right_on='sys_id', how='left').merge(df3, left_on='sys_id',right_on='sys_id', how='left').merge(df4, left_on='sys_id',right_on='sys_id', how='left').merge(df5, left_on='sys_id',right_on='sys_id', how='left').merge(df6, left_on='sys_id',right_on='sys_id', how='left').merge(df7, left_on='sys_id',right_on='sys_id', how='left')[['sys_id', 'sys_class_name', 'name', 'fqdn', 'ip_address','location.name', 'company.name', 'parents', 'childs', 'clusters', 'so', 'apps', 'services', 'business_app', 'u_impact' ]].rename(columns={'location.name':'location', 'company.name':'customer', 'ip_address':'ip', 'sys_class_name':'category', 'parents':'dependencies_parent', 'childs':'dependencies_child', 'apps':'application', 'business_app':'business_application', 'clusters':'cluster','so':'os', 'u_impact':'impact', 'fqdn':'fqdn' })

#change arrays to string concatenated with |
df_final['cluster'] = df_final['cluster'].str.join('|')
df_final['dependencies_parent'] = df_final['dependencies_parent'].str.join('|')
df_final['dependencies_child'] = df_final['dependencies_child'].str.join('|')
df_final['os'] = df_final['os'].str.join('|')
df_final['application'] = df_final['application'].str.join('|')
df_final['services'] = df_final['services'].str.join('|')
df_final['business_application'] = df_final['business_application'].str.join('|')

#reordening columns
df_final = df_final[['sys_id','category','name','fqdn','customer','ip','os','location','impact','dependencies_parent','dependencies_child','cluster','application','business_application','services']]

#send_data_bigpanda(df_final, 1000)

#generate_csv('cmdb.csv',df_final)
# Out:
#  **** TIVIT AIOPS **** - Import CMDB to BIGPANDA
#
#
# starting importing jsons...
# importing data from cmdb_server_bigpanda.json ...
# done. (122420, 9)
# importing data from cmdb_relacionamento_bigpanda.json ...
# done. (109270, 7)
# importing data from cmdb_bigpanda.json ...
# done. (333033, 21)
#
# sanitizing cmdb fields...
# extracting dataframes relationships...
# extracting cluster information from cmdb...
# extracting businessapp from cmdb...
# extractig services from cmdb...
# extracting aplication from cmdb...
# extracting operating systems from cmdb...
# create relationships with cmdb values(fqdn, sys_id)
# creating grouping and merging dataframes...
# done
#
# generating final dataframe ...

# %%
df_cmdb[df_cmdb.name=='WSPSQLBRZ025'].head()
# Out:
#        __status        company.name     dv_company.name  \
# 162360  success  ZURICH SEGUROS S/A  ZURICH SEGUROS S/A
#
#                                         dv_fqdn dv_install_status  \
# 162360  NDM Removido em: 29/11/2016 as 13:55:02              None
#
#        dv_ip_address      dv_location.name       dv_name dv_short_description  \
# 162360   172.26.3.73  TIVIT - TRANSAMERICA  WSPSQLBRZ025
#
#        dv_sys_class_name  ... dv_u_impact  \
# 162360          Servidor  ...           1
#
#                                            fqdn install_status   ip_address  \
# 162360  NDM Removido em: 29/11/2016 as 13:55:02              0  172.26.3.73
#
#                location.name          name short_description  sys_class_name  \
# 162360  TIVIT - TRANSAMERICA  WSPSQLBRZ025                    cmdb_ci_server
#
#                                   sys_id u_impact
# 162360  8c31c2dddb52bf84817ea19b8a961980        1
#
# [1 rows x 21 columns]

# %%
df_final[~pd.isnull(df_final.services)][['name','fqdn', 'category', 'services']]
df_final[~pd.isnull(df_final.business_application)][['name','fqdn', 'category', 'business_application']]
# Out:
#                               name                             fqdn  \
# 17                     TSC2 - PROD
# 66                 CONTROL-M V7 DR
# 195                     TSC2 - DEV
# 437              CONTROL-M V7 PROD
# 721                   TSC2 - ADMIN
# 732     ANALYTICS - BANCO DE DADOS
# 766           CONTROL-M V7 HOMOLOG
# 767                     TSC2 - DEV
# 105107                  SRVSVWSP15          FNIS-SRVSVWSP15.WIN.SP1
# 105313                  LNXORASP11          FNIS-LNXORASP11.LNX.SP1
# 105693                  SRVSVWSP30          FNIS-SRVSVWSP30.WIN.SP1
# 107045                  LNXETLSP01          BBCP-LNXETLSP01.LNX.SP1
# 107434                  SRVSVWSP22          FNIS-SRVSVWSP22.WIN.SP1
# 109109                  SRVSVWSP34          FNIS-SRVSVWSP34.WIN.SP1
# 109885                 LNXTRESPH01         FNIS-LNXTRESPH01.LNX.SP1
# 110729                  SRVSVWSP37          FNIS-SRVSVWSP37.WIN.SP1
# 112112              SPT-FW6843-TSM           SPT-FW6843-TSM.SEC.SP1
# 112113              SPT-FW6828-CNP           SPT-FW6828-CNP.SEC.SP1
# 112114              SPT-FW6821-TSM           SPT-FW6821-TSM.SEC.SP1
# 112381                  SRVSVWSP38          FNIS-SRVSVWSP38.WIN.SP1
# 113653              SPTCADESCOLA02       SPT-SPTCADESCOLA02.LNX.SP1
# 113790              SPT-FW6827-TSM           SPT-FW6827-TSM.SEC.SP1
# 113791              SPT-FW6829-TSM           SPT-FW6829-TSM.SEC.SP1
# 114968                ELPA11HA02PR   AESELETRO-ELPA11HA02PR.LNX.SP1
# 115252                  SRVBTCSP01          FNIS-SRVBTCSP01.WIN.SP1
# 115459              SPT-FW6844-TSM           SPT-FW6844-TSM.SEC.SP1
# 115460              SPT-FW6829-CNP           SPT-FW6829-CNP.SEC.SP1
# 116424                 SRVCONSPD01         FNIS-SRVCONSPD01.WIN.SP1
# 117040              SPT-FW6844-CNP           SPT-FW6844-CNP.SEC.SP1
# 117041              SPT-FW6828-TSM           SPT-FW6828-TSM.SEC.SP1
# ...                            ...                              ...
# 225872              SPTCADESCOLA11       SPT-SPTCADESCOLA11.LNX.SP1
# 225902                ELPA10WA14PR   AESELETRO-ELPA10WA14PR.LNX.SP1
# 225917               PMAPPMTRPRD01        USF-PMAPPMTRPRD01.LNX.SP1
# 225921                    SPTHM102             SPT-SPTHM102.LNX.SP2
# 225925              BNAPPDQLTPRD01       ALE-BNAPPDQLTPRD01.LNX.SP1
# 226048                SPTSCAPRIV12         SPT-SPTSCAPRIV12.LNX.SP2
# 226057                 VLITVTAS019          VLI-VLITVTAS019.LNX.SP1
# 226091                     SPTHM07              SPT-SPTHM07.LNX.SP1
# 226121                 SPTSCAPUB02          SPT-SPTSCAPUB02.LNX.SP1
# 226147               TBCNBUMESP110  AESELETRO-TBCNBUMESP110.LNX.SP1
# 226163                    SPTHM103             SPT-SPTHM103.LNX.SP2
# 226276               SAMUBUHVHYP02        SAM-SAMUBUHVHYP02.LNX.SP1
# 226279                  UNICNUDR04           CNU-UNICNUDR04.LNX.RJ1
# 226399                  SPTSCPFS01           SPT-SPTSCPFS01.LNX.SP1
# 226400                 SPTSCPAPP05          SPT-SPTSCPAPP05.LNX.SP1
# 226415                ELPA10HA02PR   AESELETRO-ELPA10HA02PR.LNX.SP1
# 226424                 SPTSCAPUB14          SPT-SPTSCAPUB14.LNX.SP2
# 226439                 VLITVTAS017          VLI-VLITVTAS017.LNX.SP1
# 226476                 SPTSCPWEB01          SPT-SPTSCPWEB01.LNX.SP1
# 226500                 VLITVTAS018          VLI-VLITVTAS018.LNX.SP1
# 226577                ELPA10WA08PR   AESELETRO-ELPA10WA08PR.LNX.SP1
# 226638                AESLPDB10G01   AESELETRO-AESLPDB10G01.LNX.SP1
# 226647                ELPA10WA06QA         AES-ELPA10WA06QA.LNX.RJ1
# 226654                ELPA10WA05PR   AESELETRO-ELPA10WA05PR.LNX.SP1
# 226683                   MSPFST01V            MIT-MSPFST01V.LNX.SP1
# 226734              CEBRSVC-SPAP05       SDX-CEBRSVC-SPAP05.LNX.SP1
# 226770                  UNICNUDR01           CNU-UNICNUDR01.LNX.RJ1
# 226824                BNAPPBIHML01         ALE-BNAPPBIHML01.LNX.SP1
# 226833                ELPA10WA13QA   AESELETRO-ELPA10WA13QA.LNX.RJ1
# 226856                     SPTHM09              SPT-SPTHM09.LNX.SP1
#
#                     category  \
# 17              cmdb_ci_appl
# 66              cmdb_ci_appl
# 195             cmdb_ci_appl
# 437             cmdb_ci_appl
# 721             cmdb_ci_appl
# 732             cmdb_ci_appl
# 766             cmdb_ci_appl
# 767             cmdb_ci_appl
# 105107        cmdb_ci_server
# 105313        cmdb_ci_server
# 105693        cmdb_ci_server
# 107045        cmdb_ci_server
# 107434        cmdb_ci_server
# 109109        cmdb_ci_server
# 109885        cmdb_ci_server
# 110729        cmdb_ci_server
# 112112        cmdb_ci_server
# 112113        cmdb_ci_server
# 112114        cmdb_ci_server
# 112381        cmdb_ci_server
# 113653        cmdb_ci_server
# 113790        cmdb_ci_server
# 113791        cmdb_ci_server
# 114968        cmdb_ci_server
# 115252        cmdb_ci_server
# 115459        cmdb_ci_server
# 115460        cmdb_ci_server
# 116424        cmdb_ci_server
# 117040        cmdb_ci_server
# 117041        cmdb_ci_server
# ...                      ...
# 225872  cmdb_ci_linux_server
# 225902  cmdb_ci_linux_server
# 225917  cmdb_ci_linux_server
# 225921  cmdb_ci_linux_server
# 225925  cmdb_ci_linux_server
# 226048  cmdb_ci_linux_server
# 226057  cmdb_ci_linux_server
# 226091  cmdb_ci_linux_server
# 226121  cmdb_ci_linux_server
# 226147  cmdb_ci_linux_server
# 226163  cmdb_ci_linux_server
# 226276  cmdb_ci_linux_server
# 226279  cmdb_ci_linux_server
# 226399  cmdb_ci_linux_server
# 226400  cmdb_ci_linux_server
# 226415  cmdb_ci_linux_server
# 226424  cmdb_ci_linux_server
# 226439  cmdb_ci_linux_server
# 226476  cmdb_ci_linux_server
# 226500  cmdb_ci_linux_server
# 226577  cmdb_ci_linux_server
# 226638  cmdb_ci_linux_server
# 226647  cmdb_ci_linux_server
# 226654  cmdb_ci_linux_server
# 226683  cmdb_ci_linux_server
# 226734  cmdb_ci_linux_server
# 226770  cmdb_ci_linux_server
# 226824  cmdb_ci_linux_server
# 226833  cmdb_ci_linux_server
# 226856  cmdb_ci_linux_server
#
#                                      business_application
# 17                                                   TSC2
# 66                                           CONTROL-M V7
# 195                                                  TSC2
# 437                                          CONTROL-M V7
# 721                                                  TSC2
# 732                                             ANALYTICS
# 766                                          CONTROL-M V7
# 767                                                  TSC2
# 105107  FIDELITY_PR_DI_DOWN_TB_SVIEW_VALID_SRVSVWSP15|...
# 105313  FIDELITY_BCV_END_BACKUP_LNXORASP|FIDELITY_BCV_...
# 105693  FIDELITY_PR_DI_DOWN_TB_SVIEW_VALID_SRVSVWSP30|...
# 107045  FALCON_PR_BRAD_DI_ACCOUNT_SUMMARY|FALCON_PR_BR...
# 107434  FIDELITY_PR_DI_DOWN_TB_SVIEW_EXEC_SRVSVWSP22|F...
# 109109  FIDELITY_PR_DI_DOWN_TB_SVIEW_VALID_SRVSVWSP34|...
# 109885  TRIAD_UT_BRAD_SE_A01NEWCYCLE|TRIAD_UT_BRAD_DI_...
# 110729  FIDELITY_PR_DI_DOWN_TB_SVIEW_EXEC_SRVSVWSP37|F...
# 112112  VIAÇÃO GATO PRETO LTDA (RUA ALEXANDRE MACKENZI...
# 112113        TRANSCOOPER (RUA ANTONELO DE MESSINA, 1726)
# 112114                FENIX (RUA AGENOR ALVES MEIRA, 320)
# 112381  FIDELITY_PR_DI_DOWN_TB_SVIEW_EXEC_SRVSVWSP38|F...
# 113653                                     SCA - PRODUÇÃO
# 113790                    TRANSCOOPER (RUA ANDRESSA, 101)
# 113791         TRANSCOOPER (ESTRADA DO JACU-PESSEGO, 541)
# 114968  BIT0000S.HW|BIT0000.HB|BIT0000P.HW|BIT0002S.HW...
# 115252  FIDELITY_PRD_PD_SMS_MENSAGENS_DAYCOVAL|FIDELIT...
# 115459         AMBIENTAL S.A. (RUA NESTOR DE BARROS, 289)
# 115460         TRANSCOOPER (ESTRADA DO JACU-PESSEGO, 541)
# 116424  FIDELITY_F-TRANSF_CONNECT_TESTE_CONNECT_HOMOLO...
# 117040         AMBIENTAL S.A. (RUA NESTOR DE BARROS, 289)
# 117041        TRANSCOOPER (RUA ANTONELO DE MESSINA, 1726)
# ...                                                   ...
# 225872                                     SCA - PRODUÇÃO
# 225902                                         TTB0001.SJ
# 225917                      USF_MAT_AP_DIF_LIMPACADOC3040
# 225921  SLA - CPU SERV BANCO|SLA - DISCO SERV BANCO E ...
# 225925  ALECCSSC_REPRLEG|ALEPECCL_ECVVUP|ALECCSCL_COMC...
# 226048                                     SCA - PRODUÇÃO
# 226057  VLI_OLG00U339D|VLI_OLG00U360D|VLI_OLG00U345D|V...
# 226091  SLA - CPU SERV BANCO|SLA - DISCO SERV BANCO E ...
# 226121                                     SCA - PRODUÇÃO
# 226147  AESE_EWP_BCV_050_SNAP_ARCHIVE|AESE_RP1_ARC_PRD...
# 226163  SLA - CPU SERV BANCO|SLA - DISCO SERV BANCO E ...
# 226276  SMCO_HYPERION_HML_L_10_ESSBASE|SMCO_HYPERION_H...
# 226279  CNU_CLONE_PREPROD_DR04_PRD1_STOP_DB|CNU_CLONE_...
# 226399                                     SCP - PRODUÇÃO
# 226400  SLA - DISCO SERV APLICACAO|SCP - PRODUÇÃO|SLA ...
# 226415  ARCB380.SJ|ARCB160E.SJ|ARCB470.SJ|MAND101.SJ|M...
# 226424                                     SCA - PRODUÇÃO
# 226439  VLI_OLG00U339D|VLI_OLG00U360D|VLI_OLG00U345D|V...
# 226476                                     SCP - PRODUÇÃO
# 226500  VLI_OLG00U339D|VLI_OLG00U360D|VLI_OLG00U345D|V...
# 226577  RAMB016.SJ|BILO031A.GZ|RAI0748.SJ|RAMB600.SJ|R...
# 226638  BILI111.SS|AT0310.AS|AT0059.AS|BACKUP_PJTP_DGD...
# 226647  PLMO013.QJ|ARCC311.QJ|MDMO06FF5.QJ|ARCC200.QJ|...
# 226654  RAMB016.SJ|BILO031A.GZ|RAI0748.SJ|RAMB600.SJ|R...
# 226683                             JOB_RPM_PUBLICACAO_ADB
# 226734          RCP_VALIDA_PROC|RCP_TRS_MANU|RCP_TRS_PROC
# 226770  CNU_CLONE_DR09_PRD1_START_REPLICATION_DG|CNU_C...
# 226824  ALEPLDPC_VIEWESTBLTITULFULL|ALEAATFT_AUTOSTEST...
# 226833                              MOMB022.QJ|MOMB022.QJ
# 226856  SLA - CPU SERV BANCO|SLA - DISCO SERV BANCO E ...
#
# [583 rows x 4 columns]
